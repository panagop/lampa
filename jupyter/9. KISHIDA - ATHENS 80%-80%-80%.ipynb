# %% [markdown]
#  ### ΕΙΣΑΓΩΓΗ ΒΙΒΛΙΟΘΗΚΗΣ PYSTRATA ΚΑΙ ΛΟΙΠΩΝ ΒΙΒΛΙΟΘΗΚΩΝ PYTHON

# %%
import pystrata

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from pystrata.motion import TimeSeriesMotion

# %% [markdown]
# ### ΣΥΝΑΡΤΗΣΗ ΕΙΣΑΓΩΓΗΣ ΔΙΕΓΕΡΣΗΣ ΑΠΟ txt ΑΡΧΕΙΟ

# %%
def time_accel_txt_to_pystrata_motion(filename: str) -> TimeSeriesMotion:
    df = pd.read_csv(filename, header=None, skiprows=2, encoding = "utf-8", delim_whitespace=True)
    accels = df[1].to_numpy()
    time_step = df[0][1] - df[0][0]

    return TimeSeriesMotion(filename=filename, description='', time_step=time_step, accels=accels)

# %% [markdown]
# ### ΕΙΣΑΓΩΓΗ ΑΡΧΕΙΟΥ

# %%
ts =  time_accel_txt_to_pystrata_motion('ATH49901T2.txt')

# %%
ts.accels
# Out:
# array([-1.63098879e-05, -1.12130479e-04, -3.70030581e-04, ...,
#        -1.43934760e-03, -1.22222222e-03, -3.28236493e-04])

# %%
print(ts.time_step)
# Out:
# 0.005

# %%
# Increased figure sizes
plt.rcParams["figure.dpi"] =120

# %% [markdown]
# ### ΑΠΕΙΚΟΝΙΣΗ ΓΡΑΦΗΜΑΤΟΣ ΕΠΙΤΑΧΥΝΣΙΟΓΡΑΦΗΜΑΤΟΣ

# %%
fig, ax = plt.subplots()
ax.plot(ts.times, ts.accels)
ax.set(xlabel='time (s)', ylabel='acceleration (g)')
fig.tight_layout()

# %% [markdown]
# ### ΕΙΣΑΓΩΓΗ ΕΔΑΦΙΚΩΝ ΣΤΡΩΣΕΩΝ

# %%
profile = pystrata.site.Profile(
    [
        pystrata.site.Layer(
            pystrata.site.KishidaSoilType(unit_wt=16.0, stress_vert=40, organic_content=80, lab_consol_ratio=1),
            5,
            140,
        ),
        pystrata.site.Layer(
            pystrata.site.KishidaSoilType(unit_wt=18.0, stress_vert=215, organic_content=80, lab_consol_ratio=1),
            15,
            250,
        ),
        pystrata.site.Layer(
            pystrata.site.KishidaSoilType(unit_wt=20.0, stress_vert=650, organic_content=80, lab_consol_ratio=1),
            30,
            450,
        ),
        pystrata.site.Layer(pystrata.site.SoilType("Rock", 23.0, None, 0.02), 0, 1200),
    ]
).auto_discretize()

# %% [markdown]
# ### ΓΡΑΦΗΜΑ ΒΑΘΟΥΣ-ΤΑΧΥΤΗΤΑΣ ΔΙΑΤΜΗΤΙΚΩΝ ΚΥΜΑΤΩΝ

# %%
profile.plot("initial_shear_vel")
# Out:
# <AxesSubplot:xlabel='Initial $V_s$ (m/s)', ylabel='Depth (m)'>

# %% [markdown]
# ### ΟΡΙΣΜΟΣ ΜΕΘΟΔΟΥ ΑΝΑΛΥΣΗΣ

# %%
calcs = [
    pystrata.propagation.EquivalentLinearCalculator()
]

# %% [markdown]
# ### ΟΡΙΣΜΟΣ ΕΞΑΓΟΜΕΝΩΝ

# %%
freqs = np.logspace(-1, 2, num=113)

outputs = pystrata.output.OutputCollection(
    [
        pystrata.output.ResponseSpectrumOutput(
            # Frequency
            freqs,
            # Location of the output
            pystrata.output.OutputLocation("outcrop", index=0),
            # Damping
            0.05,
        ), 
        pystrata.output.AccelTransferFunctionOutput(
            # Frequency
            freqs,
            # Location in (denominator),
            pystrata.output.OutputLocation("outcrop", index=-1),
            # Location out (numerator)
            pystrata.output.OutputLocation("outcrop", index=0),
        ),
       
    ]
)

# %%
motion = pystrata.motion.TimeSeriesMotion('ATH49901T2.txt', description='', time_step=ts.time_step, accels=ts.accels)

# %% [markdown]
# ### ΥΠΟΛΟΓΙΣΜΟΙ ΜΕΘΟΔΟΥ ΑΝΑΛΥΣΗΣ

# %%
for c in calcs:
    c(motion, profile, profile.location("outcrop", index=-1))
    outputs(c, f"{c.strain_limit:0.2f}")

# %% [markdown]
# ### ΕΚΤΥΠΩΣΗ ΓΡΑΦΗΜΑΤΩΝ

# %%
for o in outputs[:2]:
    ax = o.plot(style="indiv")

# %%
df = outputs[0].to_dataframe()
df
# Out:
#                 0.05
# 0.100000    0.001365
# 0.106362    0.001299
# 0.113128    0.001514
# 0.120325    0.001919
# 0.127980    0.001920
# ...              ...
# 78.137074   0.369349
# 83.108005   0.369195
# 88.395177   0.369058
# 94.018709   0.368937
# 100.000000  0.368829
#
# [113 rows x 1 columns]

# %%
df = outputs[1].to_dataframe()
df
# Out:
#                 0.05
# 0.100000    1.002679
# 0.106362    1.003085
# 0.113128    1.003517
# 0.120325    1.003976
# 0.127980    1.004555
# ...              ...
# 78.137074   0.225574
# 83.108005   0.154996
# 88.395177   0.155153
# 94.018709   0.122533
# 100.000000  0.100472
#
# [113 rows x 1 columns]

# %% [markdown]
# ### ΕΞΑΓΩΓΗ ΔΕΔΟΜΕΝΩΝ ΣΕ ΑΡΧΕΙΟ .xls

# %%
df = outputs[0].to_dataframe()
df.to_excel('KISHIDA 80-80-80-ATH49901T2.xlsx', index=True)
